# %%
import pandas as pd
import time

df = pd.read_csv("iot_data.csv")
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 import time
#       3
#       4 df = pd.read_csv("iot_data.csv")
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import subprocess
subprocess.run(["python", "-m", "pip", "install", "pandas"])
# Out:
# CompletedProcess(args=['python', '-m', 'pip', 'install', 'pandas'], returncode=0)

# %%
import pandas as pd
import time

df = pd.read_csv("iot_data.csv")
print(df.head())
# Out:
#              Timestamp Package_ID      Carrier          Origin  Destination  \
# 0  2025-01-01 08:00:00    PKG1000          LBC  Cagayan de Oro  Quezon City
# 1  2025-01-01 08:30:00    PKG1001  J&T Express          Manila       Manila
# 2  2025-01-01 09:00:00    PKG1002          DHL          Iloilo  Quezon City
# 3  2025-01-01 09:30:00    PKG1003          DHL          Manila       Manila
# 4  2025-01-01 10:00:00    PKG1004    Ninja Van          Manila       Makati
#
#          Status  Temperature_C  Humidity_pct  Shock_Detected  Est_Delivery_Hrs
# 0     Delivered          25.99         58.62           False              53.2
# 1     Delivered          19.55         63.19           False              12.9
# 2  At Warehouse          30.32         67.67           False               3.4
# 3     Delivered          21.68         54.75           False              14.8
# 4       Delayed          24.97         40.87           False              32.2

# %%
from web3 import Web3

ganache_url = "http://127.0.0.1:7545"
web3 = Web3(Web3.HTTPProvider(ganache_url))

if web3.is_connected():
    print("✅ Connected to Ganache successfully!")
else:
    print("❌ Connection failed. Ensure Ganache is running.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from web3 import Web3
#       2
#       3 ganache_url = "http://127.0.0.1:7545"
#       4 web3 = Web3(Web3.HTTPProvider(ganache_url))
#
# ModuleNotFoundError: No module named 'web3'

# %%
import subprocess
subprocess.run(["python", "-m", "pip", "install", "web3"])
# Out:
# CompletedProcess(args=['python', '-m', 'pip', 'install', 'web3'], returncode=0)

# %%
from web3 import Web3

ganache_url = "http://127.0.0.1:7545"
web3 = Web3(Web3.HTTPProvider(ganache_url))

if web3.is_connected():
    print("✅ Connected to Ganache successfully!")
else:
    print("❌ Connection failed. Ensure Ganache is running.")
# Out:
# ✅ Connected to Ganache successfully!

# %%
contract_address = "0x496179c4dB18b489b6D60B3c17977663606A37a7"

abi = [
    {
        "inputs": [
            {"internalType": "string", "name": "deviceId", "type": "string"},
            {"internalType": "string", "name": "dataType",  "type": "string"},
            {"internalType": "string", "name": "dataValue", "type": "string"}
        ],
        "name": "storeData",
        "outputs": [],
        "stateMutability": "nonpayable",
        "type": "function"
    },
    {
        "inputs": [],
        "name": "getTotalRecords",
        "outputs": [{"internalType": "uint256", "name": "", "type": "uint256"}],
        "stateMutability": "view",
        "type": "function"
    },
    {
        "inputs": [{"internalType": "uint256", "name": "index", "type": "uint256"}],
        "name": "getRecord",
        "outputs": [
            {"internalType": "string",  "name": "", "type": "string"},
            {"internalType": "string",  "name": "", "type": "string"},
            {"internalType": "string",  "name": "", "type": "string"},
            {"internalType": "uint256", "name": "", "type": "uint256"}
        ],
        "stateMutability": "view",
        "type": "function"
    },
    {
        "anonymous": False,
        "inputs": [
            {"indexed": False, "internalType": "string",  "name": "deviceId",  "type": "string"},
            {"indexed": False, "internalType": "string",  "name": "dataType",  "type": "string"},
            {"indexed": False, "internalType": "string",  "name": "dataValue", "type": "string"},
            {"indexed": False, "internalType": "uint256", "name": "timestamp", "type": "uint256"}
        ],
        "name": "DataStored",
        "type": "event"
    }
]

contract = web3.eth.contract(address=contract_address, abi=abi)
web3.eth.default_account = "0x96bf3de698328403fe5c2d173e658add04076747"

total_before = contract.functions.getTotalRecords().call()
print(f"✅ Connected to Smart Contract at {contract_address}")
print(f"Total Records Before Storing Data: {total_before}")
# Out:
# ---------------------------------------------------------------------------
# InvalidAddress                            Traceback (most recent call last)
# Cell In[7], line 50
#      46
#      47 contract = web3.eth.contract(address=contract_address, abi=abi)
#      48 web3.eth.default_account = "0x96bf3de698328403fe5c2d173e658add04076747"
#      49
# ---> 50 total_before = contract.functions.getTotalRecords().call()
#      51 print(f"✅ Connected to Smart Contract at {contract_address}")
#      52 print(f"Total Records Before Storing Data: {total_before}")
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\web3\contract\contract.py:291, in ContractFunction.call(self, transaction, block_identifier, state_override, ccip_read_enabled)
#     287 block_id = parse_block_identifier(self.w3, block_identifier)
#     289 abi_element_identifier = abi_to_signature(self.abi)
# --> 291 return call_contract_function(
#     292     self.w3,
#     293     self.address,
# ...

# %%
contract_address = "0x496179c4dB18b489b6D60B3c17977663606A37a7"

abi = [
    {
        "inputs": [
            {"internalType": "string", "name": "deviceId", "type": "string"},
            {"internalType": "string", "name": "dataType",  "type": "string"},
            {"internalType": "string", "name": "dataValue", "type": "string"}
        ],
        "name": "storeData",
        "outputs": [],
        "stateMutability": "nonpayable",
        "type": "function"
    },
    {
        "inputs": [],
        "name": "getTotalRecords",
        "outputs": [{"internalType": "uint256", "name": "", "type": "uint256"}],
        "stateMutability": "view",
        "type": "function"
    },
    {
        "inputs": [{"internalType": "uint256", "name": "index", "type": "uint256"}],
        "name": "getRecord",
        "outputs": [
            {"internalType": "string",  "name": "", "type": "string"},
            {"internalType": "string",  "name": "", "type": "string"},
            {"internalType": "string",  "name": "", "type": "string"},
            {"internalType": "uint256", "name": "", "type": "uint256"}
        ],
        "stateMutability": "view",
        "type": "function"
    },
    {
        "anonymous": False,
        "inputs": [
            {"indexed": False, "internalType": "string",  "name": "deviceId",  "type": "string"},
            {"indexed": False, "internalType": "string",  "name": "dataType",  "type": "string"},
            {"indexed": False, "internalType": "string",  "name": "dataValue", "type": "string"},
            {"indexed": False, "internalType": "uint256", "name": "timestamp", "type": "uint256"}
        ],
        "name": "DataStored",
        "type": "event"
    }
]

contract = web3.eth.contract(address=contract_address, abi=abi)
web3.eth.default_account = Web3.to_checksum_address("0x96bf3de698328403fe5c2d173e658add04076747")

total_before = contract.functions.getTotalRecords().call()
print(f"✅ Connected to Smart Contract at {contract_address}")
print(f"Total Records Before Storing Data: {total_before}")
# Out:
# ---------------------------------------------------------------------------
# InsufficientDataBytes                     Traceback (most recent call last)
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\web3\contract\utils.py:204, in call_contract_function(w3, address, normalizers, abi_element_identifier, transaction, block_id, contract_abi, abi_callable, state_override, ccip_read_enabled, decode_tuples, *args, **kwargs)
#     203 try:
# --> 204     output_data = w3.codec.decode(output_types, return_data)
#     205 except DecodingError as e:
#     206     # Provide a more helpful error message than the one provided by
#     207     # eth-abi-utils
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\eth_abi\codec.py:162, in ABIDecoder.decode(self, types, data, strict)
#     160 stream = self.stream_class(data)
# --> 162 return cast(Tuple[Any, ...], decoder(stream))
#
# ...

# %%
contract_address = "0x090f65a5128C183294816008589A6231A5b43A8d"

abi = [
    {
        "inputs": [
            {"internalType": "string", "name": "_deviceOrId", "type": "string"},
            {"internalType": "string", "name": "_dataType",   "type": "string"},
            {"internalType": "string", "name": "_value",      "type": "string"}
        ],
        "name": "storeData",
        "outputs": [],
        "stateMutability": "nonpayable",
        "type": "function"
    },
    {
        "inputs": [],
        "name": "getRecordCount",
        "outputs": [{"internalType": "uint256", "name": "", "type": "uint256"}],
        "stateMutability": "view",
        "type": "function"
    },
    {
        "inputs": [{"internalType": "uint256", "name": "_index", "type": "uint256"}],
        "name": "getRecord",
        "outputs": [
            {"internalType": "string",  "name": "deviceOrId", "type": "string"},
            {"internalType": "string",  "name": "dataType",   "type": "string"},
            {"internalType": "string",  "name": "value",      "type": "string"},
            {"internalType": "uint256", "name": "timestamp",  "type": "uint256"}
        ],
        "stateMutability": "view",
        "type": "function"
    },
    {
        "anonymous": False,
        "inputs": [
            {"indexed": False, "internalType": "string",  "name": "deviceOrId", "type": "string"},
            {"indexed": False, "internalType": "string",  "name": "dataType",   "type": "string"},
            {"indexed": False, "internalType": "string",  "name": "value",      "type": "string"},
            {"indexed": False, "internalType": "uint256", "name": "timestamp",  "type": "uint256"}
        ],
        "name": "DataStored",
        "type": "event"
    }
]

contract = web3.eth.contract(address=contract_address, abi=abi)
web3.eth.default_account = Web3.to_checksum_address("0xE53EFC8eA373685d24d88d3e65411ff469a79487")

total_before = contract.functions.getRecordCount().call()
print(f"✅ Connected to Smart Contract at {contract_address}")
print(f"Total Records Before Storing Data: {total_before}")
# Out:
# ✅ Connected to Smart Contract at 0x090f65a5128C183294816008589A6231A5b43A8d
# Total Records Before Storing Data: 0

# %%
def send_iot_data(device_id, data_type, data_value):
    txn = contract.functions.storeData(device_id, data_type, data_value).transact({
        'from': web3.eth.default_account,
        'gas': 3000000
    })
    receipt = web3.eth.wait_for_transaction_receipt(txn)
    print(f"✅ {device_id} | {data_type} | {data_value}°C | Txn: {receipt.transactionHash.hex()}")

for _, row in df.iterrows():
    send_iot_data(
        str(row["Package_ID"]),
        str(row["Status"]),
        str(row["Temperature_C"])
    )
    time.sleep(1)
# Out:
# ✅ PKG1000 | Delivered | 25.99°C | Txn: cc84a92fa79b7bc1302744ff00c34c2b86c1ea34ea0c01816c8685813fc8ec00
# ✅ PKG1001 | Delivered | 19.55°C | Txn: 2b6d1d5662eefbaaeefd5a1fc9b0fa15e35fc20a8fed564227be4bb7e939398e
# ✅ PKG1002 | At Warehouse | 30.32°C | Txn: 72b06f8363639c19ec34342e525b3cc81e047db068ed25bb3e5bb45bebee68b2
# ✅ PKG1003 | Delivered | 21.68°C | Txn: 0e205c8ef582da364c52aa0e9ca2de52a8477528bf681a75f395a91777241e5f
# ✅ PKG1004 | Delayed | 24.97°C | Txn: 22c7e13ceb738b24bbe26f578b201d307fc82535bd26b26ce597b22907b66646
# ✅ PKG1005 | Delayed | 27.27°C | Txn: 27d40cef9f4b8a7e5c1a7eae46118cee37fbaa315720c9bd59b1808349f23f3d
# ✅ PKG1006 | Delayed | 20.37°C | Txn: d1fafa134a640ecb2e7a914cb4ba22b781369b241dc449ea7d997ca46ac9c7f7
# ✅ PKG1007 | Out for Delivery | 21.48°C | Txn: d214a952fb9ac4c7d92680867d9e3b9e822899e11def491d35fe027c6bb9056a
# ✅ PKG1008 | At Warehouse | 21.82°C | Txn: 9ac5c4c8198821bb8f488867319265b39a2c0dbf611ebf33ae117ae7927ea1a5
# ...

# %%
total_records = contract.functions.getRecordCount().call()
print(f"Total IoT records stored: {total_records}")

record = contract.functions.getRecord(0).call()
print("First Stored Record:", record)
# Out:
# Total IoT records stored: 100
# First Stored Record: ['PKG1000', 'Delivered', '25.99', 1780405200]
